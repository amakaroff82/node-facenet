# %%
import pandas as pd
import tensorflow as tf
import scipy as sc
from scipy.spatial import distance
import cv2
import numpy as np
import threading
import time
import datetime
from multiprocessing import Queue
import os
import json
from base64 import b64encode
from typing import (
    Any,
    List,
    Tuple,
)

import align.detect_face    # type: ignore
import facenet              # type: ignore

import matplotlib.pyplot as pl
# %matplotlib inline

# %%
#base_path = "/mnt/d/nna/"
base_path = "d:/nna/"
minimum_size_of_face = 60

frames = Queue(1)
faces = Queue(1)

STEP = 4

# %%
data_path = base_path + "data/"
facenet_path = base_path + "node-facenet/"
model_path = facenet_path + "models/"

# %%
class MtcnnBridge():
    """
    MTCNN Face Alignment
    """
    def __init__(self) -> None:
        self.graph = self.session = None            # type: Any
        self.pnet = self.rnet = self.onet = None    # type: Any

        self.minsize = minimum_size_of_face # minimum size of face
        self.threshold = [0.6, 0.7, 0.7]    # three steps's threshold
        self.factor = 0.709                 # scale factor

    def init(self) -> None:
        """ doc """

        self.graph = tf.Graph()
        self.session = tf.Session(graph=self.graph)

        # pylint: disable=not-context-manager
        with self.graph.as_default():
            with self.session.as_default():
                self.pnet, self.rnet, self.onet = \
                    align.detect_face.create_mtcnn(self.session, None)

    def align(
            self,
            image: np.ndarray,
    ) -> Tuple[List[Any], List[Any]]:
        """ doc """

        bounding_boxes, landmarks = align.detect_face.detect_face(
            image,   # get rid of alpha channel(if any)
            self.minsize,
            self.pnet,
            self.rnet,
            self.onet,
            self.threshold,
            self.factor,
        )

        return bounding_boxes.tolist(), landmarks.tolist()

# %%
class FacenetBridge(object):
    """
    Bridge of Facenet
    """
    FACENET_MODEL = None   # type: str

    def __init__(self) -> None:
        self.graph = self.session = None        # type: Any

        self.placeholder_input = None           # type: Any
        self.placeholder_phase_train = None     # type: Any
        self.placeholder_embeddings = None      # type: Any

        self.FACENET_MODEL = FacenetBridge.get_model_path()

    def init(self) -> None:
        """ doc """
        self.graph = tf.Graph()
        self.session = tf.Session(graph=self.graph)

        # pylint: disable=not-context-manager
        with self.graph.as_default():
            with self.session.as_default():
                model_dir = os.path.expanduser(self.FACENET_MODEL)
                meta_file, ckpt_file = facenet.get_model_filenames(model_dir)
                saver = tf.train.import_meta_graph(
                    os.path.join(model_dir, meta_file),
                )
                saver.restore(
                    tf.get_default_session(),
                    os.path.join(model_dir, ckpt_file),
                )
                # facenet.load_model(self.FACENET_MODEL)

        self.placeholder_input = self.graph.get_tensor_by_name('input:0')
        self.placeholder_phase_train = \
            self.graph.get_tensor_by_name('phase_train:0')
        self.placeholder_embeddings = \
            self.graph.get_tensor_by_name('embeddings:0')

    @staticmethod
    def get_model_path() -> str:
        return model_path    
    
    def embeddings(
            self,
            images: np.ndarray
    ) -> np.ndarray:
        """
        Get embeddings
        """

        slices = np.empty((len(images), 160, 160, 3))
        for i in range(len(images)):
            slices[i,:,:,:] = facenet.prewhiten(images[i])
            
        feed_dict = {
            self.placeholder_input:         slices,
            self.placeholder_phase_train:   False,
        }
        # Use the facenet model to calcualte embeddings
        embeddings = self.session.run(
            self.placeholder_embeddings,
            feed_dict=feed_dict,
        )

        #print("images " + str(len(images)))
        #print("emb " + str(len(embeddings)))
        
        # Return the only row
        return embeddings

# %%
class MtcnnMain(threading.Thread):
    
    def __init__(self):
        threading.Thread.__init__(self)
        self.initNN()

    def initNN(self):
        self.mtcnn = MtcnnBridge()
        self.mtcnn.init()

    def run(self):
        print("Mtcnn thread: run")
        global frames
        global faces
        
        while True:
            #if(not frames.empty()):
                #remove extra faces
                if (faces.full()): #skip oweloaded faces
                    faces.get()
                
                #if frames.full(): #skip owerloaded frames
                    #frames.get()
                    
                frame = frames.get() 
                
                a = datetime.datetime.now()
                areas = self.mtcnn.align(frame[1])[0]                
                areasCount = len(areas)

                b = datetime.datetime.now()
                #print("Mtcnn align: " + str(b - a))     
                
                
                
                if (not areasCount == 0):
                    a = datetime.datetime.now()
                    
                    fullSize = frame[0]
                    height = np.size(fullSize, 0)
                    width = np.size(fullSize, 1)

                    positions = np.empty((areasCount, 4))
                    embeddings = np.empty((areasCount, 160, 160, 3))

                    for i in range(areasCount):
                        pos = areas[i]
                        x = max(int(pos[0] * STEP), 0)
                        y = max(int(pos[1] * STEP), 0)
                        w = min(int(pos[2] * STEP), width)
                        h = min(int(pos[3] * STEP), height)
                        
                        positions[i,:] = [x,y,w,h] 
                        
                        img = fullSize[y:h, x:w, 0:3]
                        
                        
                        img = cv2.resize(img, dsize=(160, 160), interpolation=cv2.INTER_CUBIC)  
                        embeddings[i,:,:,:] = img 
                        
                        print(str(np.size(img, 1)) + " x " + str(np.size(img, 0)))

                    if (not faces.full()):
                        faces.put([positions, embeddings])
                        
                    b = datetime.datetime.now()
                    print("Mtcnn resizing: " + str(b - a))        

            #else:
                #print("Mtcnn Idle")
                time.sleep(0.001)

# %%
class FacenetMain(threading.Thread):
    
    def __init__(self):
        threading.Thread.__init__(self)
        self.user = []
        self.distances = []        
        self.loadUsers()
        self.initNN()

    def loadUsers(self):
        dataFile = "./data.json"
        file = open(dataFile, "r")
        self.users = json.loads(file.read())
        
    def initNN(self):
        self.face = FacenetBridge()
        self.face.init()

    def trackSessions(self, emb):
        a = datetime.datetime.now()
        nearDistances = []
        for user in self.users:
            userEmb = user['embedding']        
            userName = user['name']

            dist = distance.euclidean(userEmb, emb)
            if dist < 1.0:
                nearDistances.append((userName, dist))
                
        if(len(nearDistances) > 0):
            newlist = sorted(nearDistances, key=lambda x: x[1]) 

            print(newlist[0][0] + " - " + str(newlist[0][1]))
            
            self.distances.append(newlist[0][1])
        b = datetime.datetime.now()
        #print("Tracking sessions: " + str(b - a))
        
    def run(self):
        print("Facenet thread: run")
        
        global faces
        
        while True:
            if(not faces.empty()):
         
                #if faces.full(): # skip owerloaded faces
                    #faces.get()
                    
                facesOnScreen = faces.get()
                
                a = datetime.datetime.now()
                
                positions = facesOnScreen[0]
                images = facesOnScreen[1]
                                
                embeddings = self.face.embeddings(images)
                
                for emb in embeddings:                    
                    self.trackSessions(emb)      
                    
                b = datetime.datetime.now()   
                print("Facenet: " + str(b - a))
            #else:
                #print("Facenet Idle")
            time.sleep(0.005)

# %%
class ImageGrabber(threading.Thread):
    def __init__(self, ID):
        threading.Thread.__init__(self)
        self.ID=ID
        self.restartGrabber()

    def restartGrabber(self):
        self.cam=cv2.VideoCapture(self.ID)
        
    def run(self):
        print("Image grabber thread: run")
        
        global frames
        
        while True:
            #print('start')
            
            ret, frame=self.cam.read()
            if (ret):
                if(not frames.empty()):
                    time.sleep(0.001)
                    continue
                    
                # remove extra frames
                
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                height = np.size(frame, 0)
                width = np.size(frame, 1)
                
                #print("h: " + str(height) + " w: "+ str(width))
                frame2 = cv2.resize(frame, dsize=(int(width / STEP), int(height / STEP)), interpolation=cv2.INTER_CUBIC)

                
                if (frames.empty()):
                    a = datetime.datetime.now()
                    frames.put([frame, frame2])
                    b = datetime.datetime.now()
                    #print("Grabber: " + str(b - a))

                    
            else:
                print('Grabber Idle')
                self.restartGrabber()
                
            time.sleep(0.001)

# %%
mtcnnCount = 1
facenetCount = 1

mtcnnInstances = []
facenetInstances = []

#grabberInstance = ImageGrabber(0)
grabberInstance = ImageGrabber("rtsp://guest:sup3rGu3st@@10.10.101.156/ch1_1.h264")

for i in range(mtcnnCount):
    mtcnnInstances.append(MtcnnMain())
    
for i in range(facenetCount):
    facenetInstances.append(FacenetMain())

grabberInstance.start()

for mtcnn in mtcnnInstances:
    mtcnn.start()

for fn in facenetInstances:
    fn.start()
    fn.join()

for mtcnn in mtcnnInstances:
    mtcnn.join()

grabberInstance.join()
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from d:/nna/node-facenet/models/model-20170512-110547.ckpt-250000
# Image grabber thread: run
# Mtcnn thread: run
# Facenet thread: run
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.072120
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031215
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.032568
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016387
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015579
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020012
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015626
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.048028
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023981
# Mtcnn align: 0:00:00.015647
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031240
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024145
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.041055
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031209
# Mtcnn align: 0:00:00.015583
# Grabber: 0:00:00
# Grabber: 0:00:00Mtcnn align: 0:00:00.015621
#
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015618
# Grabber Idle
# Mtcnn align: 0:00:00.024000
# Grabber: 0:00:00
# Grabber: 0:00:00Mtcnn align: 0:00:00.015657
#
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015533
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015529
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031207
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.042957
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028443
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031259
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015583
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.039812
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019948
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031250
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.021510
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012238
# Mtcnn align: 0:00:00.015577
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031985
# Mtcnn align: 0:00:00.012174
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020001Grabber: 0:00:00
#
# Mtcnn align: 0:00:00.016141
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015619
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015629
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015562
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015629
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015655
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015637
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004728
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020070
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024031
# Mtcnn align: 0:00:00.015534
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015616
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020324
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015622
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004176
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015660
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015628
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012565
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023981
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031205
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031247
# Mtcnn align: 0:00:00.036997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008129
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015619
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015637
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012046
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011978
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008110
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015664
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015628
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015619
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004272
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028216
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015586
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015620
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.027982
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004270
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015685
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015617
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015572
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031236
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015581
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012041
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015626
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016062
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020027
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015572
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015583
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016008
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008124
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023975
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015652
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016710
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015616
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015624
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016049
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015647
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016805
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011964
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015637
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015987
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016008
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015982
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028006
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.040001
# Grabber: 0:00:00.004002
# Mtcnn align: 0:00:00.015634
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016006
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016025
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019965
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019959
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015983
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015938
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015961
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015965
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016031
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015986
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015959
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020024
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016049
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020009
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019965
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016095
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016044
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016072
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015961
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015987
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031996
# Mtcnn align: 0:00:00.016041
# Grabber: 0:00:00.003998
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015967
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015618
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015979
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015624
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015577
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.040944
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019969
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015619
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015617
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012034
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016052
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020024
# Grabber: 0:00:00
# Grabber: 0:00:00Mtcnn align: 0:00:00.027998
#
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024006
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024015
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019980
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020015
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012024
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012527
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012041
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015615
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015637
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015626
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015964
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031288
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.046885
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016466
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015605
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015663
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015617
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015615
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015566
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015589
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015620
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015622
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015614
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015607
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011985
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008172
# Grabber: 0:00:00.004000
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015628
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019455
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015595
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008117
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015908
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016034
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004244
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.041448
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019988
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016040
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019975
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031237
# Mtcnn align: 0:00:00.015528
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019986
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004430
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.028001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015604
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019985
# Grabber: 0:00:00.015609
# Mtcnn align: 0:00:00.019989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004075
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015572
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015640
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008218
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012059
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015622
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015579
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015608
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015665
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.000098
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015665
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016013
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015622
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008413
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008455
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015630
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015975
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016092
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008237
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020271
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016035
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019959
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019964
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015619
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016042
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016033
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015629
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015589
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024029
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019970
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011967
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020294
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011957
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016006
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015620
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012008
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019991
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015617
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019984
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.029862
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015986
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020016
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.029383
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020177
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008311
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019975
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004461
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015661
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015576
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015657
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015624
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024064
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00.003997
# Mtcnn align: 0:00:00.012047
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015568
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015572
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012262
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020015
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016026
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015634
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016036
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016058
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016265
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016047
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004246
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015990
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019858
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024003
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019988
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004709
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015584
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020016
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015988
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019983
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004108
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020034
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004294
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012317
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015668
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016006
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016054
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012046
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024344
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024479
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024246
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015629
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016013
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019922
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015623
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015618
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016062
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.006033
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016840
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015630
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015978
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019963
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015618
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015599
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015583
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015972
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012043
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015608
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015597
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019945
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016002
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019981
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020012
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016027
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016007
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019963
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023981
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004285
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015668
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015628
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012091
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019987
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019969
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015964
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015616
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020235
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015628
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016034
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020608
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031246
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015579
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004076
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016702
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015629
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015993
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020005
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016008
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020015
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.023943
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016004
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004294
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012394
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015999
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016054
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019972
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015620
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015627
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.020000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019996
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.031291
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015989
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016012
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024001
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015986
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019966
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015635
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.008438
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016049
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015998
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.019995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015626
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015997
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015620
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015631
# Grabber: 0:00:00.015104
# Mtcnn align: 0:00:00.012045
# Grabber: 0:00:00
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012000
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004329
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012216
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016392
# Grabber: 0:00:00
# Grabber: 0:00:00Mtcnn align: 0:00:00.020333
#
# Mtcnn align: 0:00:00.015553
# Grabber: 0:00:00.003996
# Mtcnn align: 0:00:00
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.024260
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015674
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011994
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015625
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.011992
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015995
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.004324
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015580
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015613
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.012049
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015621
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016056
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.016215
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015590
# Grabber: 0:00:00
# Mtcnn align: 0:00:00.015588
